# %%
import numpy as np
import pandas  as pd
from pandas import Series,DataFrame

# %%
df=pd.read_csv('my_csv.csv')
df
# Out:
#    q  r  s  t Rajasthan
# 0  2  3  4  5    Jaipur
# 1  a  s  d  f     Ajmer
# 2  6  7  8  9   Jodhpur

# %%
df1=pd.read_csv('my_csv.csv',header=None)
df1
# Out:
#    0  1  2  3          4
# 0  q  r  s  t  Rajasthan
# 1  2  3  4  5     Jaipur
# 2  a  s  d  f      Ajmer
# 3  6  7  8  9    Jodhpur

# %%
df1.columns=['a','b','c','d','e']
df1
# Out:
#    a  b  c  d          e
# 0  q  r  s  t  Rajasthan
# 1  2  3  4  5     Jaipur
# 2  a  s  d  f      Ajmer
# 3  6  7  8  9    Jodhpur

# %%
pd.read_csv('my_csv.csv',header=None,nrows=3)
# Out:
#    0  1  2  3          4
# 0  q  r  s  t  Rajasthan
# 1  2  3  4  5     Jaipur
# 2  a  s  d  f      Ajmer

# %%
df2=df1.drop(1)

# %%
df2
# Out:
#    a  b  c  d          e
# 0  q  r  s  t  Rajasthan
# 2  a  s  d  f      Ajmer
# 3  6  7  8  9    Jodhpur

# %%
df3=df1.drop('d',axis=1)

# %%
df3
# Out:
#    a  b  c          e
# 0  q  r  s  Rajasthan
# 1  2  3  4     Jaipur
# 2  a  s  d      Ajmer
# 3  6  7  8    Jodhpur

# %%
df3.to_csv('my_csv_out.csv')

# %%
df3
# Out:
#    a  b  c          e
# 0  q  r  s  Rajasthan
# 1  2  3  4     Jaipur
# 2  a  s  d      Ajmer
# 3  6  7  8    Jodhpur

# %%
df4=pd.read_csv('my_csv_out.csv')

# %%
df4
# Out:
#    Unnamed: 0  a  b  c          e
# 0           0  q  r  s  Rajasthan
# 1           1  2  3  4     Jaipur
# 2           2  a  s  d      Ajmer
# 3           3  6  7  8    Jodhpur
